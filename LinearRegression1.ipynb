# %% [markdown]
# <a href="https://colab.research.google.com/github/TKing151/MachineLearning/blob/main/LinearRegression1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pydataset
from pydataset import data
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.9 MB 2.6 MB/s
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939432 sha256=bba650028db7248d8f899ff1405a76a78eb181257ac310324aec96a7e15c78d0
#   Stored in directory: /root/.cache/pip/wheels/d7/e5/36/85d319586b4a405d001029d489102f526ce5546248c295932a
# Successfully built pydataset
# ...
# initiated datasets repo at: /root/.pydataset/

# %%
# %matplotlib inline

# %%
pima = data('Pima.tr')

# %%
pima.plot(kind='scatter', x='skin', y='bmi')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(pima.skin, pima.bmi)

# %%
plt.scatter(x_train, y_train, label='training data', color = 'r', alpha = .7)
plt.scatter(x_test, y_test, label = 'test data', color = 'b', alpha =.7)
plt.legend()
plt.show()

# %%
lr = LinearRegression()

# %%
lr.fit(x_train.values.reshape(-1, 1), y_train.values)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(x_test.values.reshape(-1, 1))

# %%
plt.plot(x_test, prediction, label='linear regression', color='g')
plt.scatter(x_test, y_test, label='actual test vals', color='r')
plt.legend()
plt.show()

# %%
lr.score(x_test.values.reshape(-1,1), y_test.values)
# Out:
# 0.46789836630154147
